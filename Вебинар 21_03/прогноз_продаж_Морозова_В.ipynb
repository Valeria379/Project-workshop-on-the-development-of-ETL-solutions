# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f59301f4-54b8-458b-ae9b-3264d70efc94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f59301f4-54b8-458b-ae9b-3264d70efc94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install dill
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 2.5 MB/s eta 0:00:00
# ...

# %%
import joblib
model = joblib.load("ml_model (2).pkl")
import pandas as pd
print(model.predict(pd.DataFrame({'temperature': [25]})))
# Out:
# [219.02705552]

# %%
print(model.predict(pd.DataFrame({'temperature': [10]})))
# Out:
# [212.04356992]

# %%
print(model.predict(pd.DataFrame({'temperature': [5]})))
# Out:
# [209.71574139]

# %%
print(model.predict(pd.DataFrame({'temperature': [40]})))
# Out:
# [226.01054111]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-845d3e24-eadc-4c7e-8a72-412baed1a1e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-845d3e24-eadc-4c7e-8a72-412baed1a1e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b74369d-68bf-4491-a5fb-026f2861f3d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b74369d-68bf-4491-a5fb-026f2861f3d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("joined_data (2).csv", delimiter=',')
data
# Out:
#           date  temperature  sales
# 0   2025-03-21          7.2    151
# 1   2025-03-22          7.9    276
# 2   2025-03-23          2.3    296
# 3   2025-03-24          8.1    202
# 4   2025-03-25          9.4    268
# 5   2025-03-26          7.4     72
# 6   2025-03-27          6.2    256
# 7   2025-03-28          4.1     51
# 8   2025-03-29          1.3    237
# 9   2025-03-30          4.8    182
# 10  2025-03-31          6.5    295
# 11  2025-04-01          5.7    269
# 12  2025-04-02          2.5    282
# 13  2025-04-03          3.0    102

# %%
#проверка на наличие нулевых значений
data.isna().sum().sum()/len(data)
# Out:
# np.float64(0.0)

# %%
#отбрасывание нулевых значений
data.dropna(inplace=True)

# %%
data_temp = pd.read_csv("weather_forecast (2).csv", delimiter=',')
data_temp
# Out:
#           date  temperature
# 0   2025-03-21          7.2
# 1   2025-03-22          7.9
# 2   2025-03-23          2.3
# 3   2025-03-24          8.1
# 4   2025-03-25          9.4
# 5   2025-03-26          7.4
# 6   2025-03-27          6.2
# 7   2025-03-28          4.1
# 8   2025-03-29          1.3
# 9   2025-03-30          4.8
# 10  2025-03-31          6.5
# 11  2025-04-01          5.7
# 12  2025-04-02          2.5
# 13  2025-04-03          3.0
